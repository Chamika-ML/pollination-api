# %%
import requests
import pandas as pd
import numpy as np
import time
from datetime import datetime,timezone,timedelta
import pytz #time zone data

# %%
def unix_to_aus(time):
    
    """this function convert UNIX date time to Austrelia  date time and output will be string"""
    
    time_int = int(time) #get integer value
    
    time_zone = timezone(timedelta(seconds=36000)) # time zone of Austrelia 
    
    aus_time = datetime.fromtimestamp(time_int, tz = time_zone).strftime('%Y-%m-%d %H:%M:%S')
    #aus_time = datetime.fromtimestamp(time_int, tz = time_zone)
    
    return aus_time

# %%
def find_solar_seconds(Sunrise,Sunset):
    
    """ this function got two datetime vectors and return the time diffrence between each two elements in seconds as an array """
    
    Timedelta_list = [] # tiem diffrence list
    
    for i in range(len(Sunrise)):
        
        Timedelta_str_whole = Sunset[i] - Sunrise[i] # output example: Timedelta('0 days 12:17:55')
        Timedelta_str_time = str(Timedelta_str_whole).split()[2] # output example : '12:17:55'
        Timedelta_str_num = Timedelta_str_time.split(':') # output example: ['12', '17', '55'] 
        Timedelta_num = [int(i) for i in Timedelta_str_num] # output example: [12, 17, 55]
        
        Timedelta_sconds = Timedelta_num[0]*3600 + Timedelta_num[1]*60 + Timedelta_num[2] # output example: 44275
        
        Timedelta_list.append(Timedelta_sconds)
        
    return np.array(Timedelta_list)

# %% [markdown]
# ### Load and understand data

# %%
grid_point_dataset = pd.read_csv("../spatial/data/csv/grid70m_points.csv")

# %%
grid_point_Weather_data = pd.DataFrame(columns=["Time","Id","Longitude", "Latitude","Tempreture", "Humidity","Wind speed","Weather ID", "Weather ID group", "Weather ID description", "Sunrise", "Sunset"])

# %%
grid_point_dataset.head()
# Out:
#    id   Longitude   Latitude  Probability
# 0   1  143.251973 -35.083201     0.347612
# 1   2  143.251973 -35.084201     0.867893
# 2   3  143.251973 -35.085201     0.443985
# 3   4  143.251973 -35.086201     0.055013
# 4   5  143.251973 -35.087201     0.016234

# %%
grid_point_dataset.isnull().sum()
# Out:
# id             0
# Longitude      0
# Latitude       0
# Probability    0
# dtype: int64

# %%
grid_point_Weather_data.head()
# Out:
# Empty DataFrame
# Columns: [Time, Id, Longitude, Latitude, Tempreture, Humidity, Wind speed, Weather ID, Weather ID group, Weather ID description, Sunrise, Sunset]
# Index: []

# %% [markdown]
# ###  Call API and get gata into data frame

# %%
longitudes = np.array(grid_point_dataset["Longitude"])
latitudes = np.array(grid_point_dataset["Latitude"])

# %%
longitudes
# Out:
# array([143.25197304, 143.25197304, 143.25197304, ..., 143.31697304,
#        143.31697304, 143.31697304])

# %%
int(len(latitudes)/4)
# Out:
# 990

# %%
srt_time  = datetime.now()
piangil_timezone = pytz.timezone('Australia/Sydney')

for i in range(int(len(latitudes)/4)): # contralls the amount of the data
    
    srt_time_point  = datetime.now()
    #get the lat long coordinates
    lat = latitudes[4*i] 
    long = longitudes[4*i]
    
    #API url
    url = "https://api.openweathermap.org/data/2.5/weather?lat={}&lon={}&appid=8ee842d65cf08ec205365865e3d53348&units=metric".format(lat,long)
    
    piangil_time = datetime.now(piangil_timezone) #get time in Australia for data set
    
    #get data form API as json data
    res = requests.get(url)
    data = res.json()
    
    # create the data list that we want from the json data 
    data_vec = [piangil_time, 4*i+1, long, lat, data["main"]["temp"], data["main"]["humidity"], data["wind"]["speed"], data["weather"][0]["id"], data["weather"][0]["main"], data["weather"][0]["description"], unix_to_aus(data["sys"]["sunrise"]), unix_to_aus(data["sys"]["sunset"])]
    data_vec_1 = [piangil_time, 4*i+1+1, longitudes[4*i+1], latitudes[4*i+1], data["main"]["temp"], data["main"]["humidity"], data["wind"]["speed"], data["weather"][0]["id"], data["weather"][0]["main"], data["weather"][0]["description"], unix_to_aus(data["sys"]["sunrise"]), unix_to_aus(data["sys"]["sunset"])]
    data_vec_2 = [piangil_time, 4*i+2+1, longitudes[4*i+2], latitudes[4*i+2], data["main"]["temp"], data["main"]["humidity"], data["wind"]["speed"], data["weather"][0]["id"], data["weather"][0]["main"], data["weather"][0]["description"], unix_to_aus(data["sys"]["sunrise"]), unix_to_aus(data["sys"]["sunset"])]
    data_vec_3 = [piangil_time, 4*i+3+1, longitudes[4*i+3], latitudes[4*i+3], data["main"]["temp"], data["main"]["humidity"], data["wind"]["speed"], data["weather"][0]["id"], data["weather"][0]["main"], data["weather"][0]["description"], unix_to_aus(data["sys"]["sunrise"]), unix_to_aus(data["sys"]["sunset"])]
    
    #update the data frame
    grid_point_Weather_data.loc[4*i] = data_vec
    grid_point_Weather_data.loc[4*i+1] = data_vec_1
    grid_point_Weather_data.loc[4*i+2] = data_vec_2
    grid_point_Weather_data.loc[4*i+3] = data_vec_3
    
    
    
    time.sleep(0.1)
    end_time_point  = datetime.now()
    print(f"step {i+1} is completed! and taken {end_time_point-srt_time_point} time to complete")
    
    
    
end_time = datetime.now()
total_execution_time = end_time-srt_time
print(f"the programe take: {total_execution_time} to complete" )
# Out:
# step 1 is completed! and taken 0:00:00.885062 time to complete
# step 2 is completed! and taken 0:00:01.066986 time to complete
# step 3 is completed! and taken 0:00:00.928121 time to complete
# step 4 is completed! and taken 0:00:01.043046 time to complete
# step 5 is completed! and taken 0:00:01.031879 time to complete
# step 6 is completed! and taken 0:00:00.957233 time to complete
# step 7 is completed! and taken 0:00:00.898721 time to complete
# step 8 is completed! and taken 0:00:00.874400 time to complete
# step 9 is completed! and taken 0:00:01.017258 time to complete
# step 10 is completed! and taken 0:00:01.112369 time to complete
# step 11 is completed! and taken 0:00:01.013407 time to complete
# step 12 is completed! and taken 0:00:00.984553 time to complete
# step 13 is completed! and taken 0:00:00.962132 time to complete
# step 14 is completed! and taken 0:00:00.949355 time to complete
# step 15 is completed! and taken 0:00:00.937889 time to complete
# step 16 is completed! and taken 0:00:01.038969 time to complete
# step 17 is completed! and taken 0:00:01.128070 time to complete
# step 18 is completed! and taken 0:00:01.585479 time to complete
# step 19 is completed! and taken 0:00:01.229327 time to complete
# step 20 is completed! and taken 0:00:00.906392 time to complete
# step 21 is completed! and taken 0:00:00.963699 time to complete
# step 22 is completed! and taken 0:00:00.961840 time to complete
# step 23 is completed! and taken 0:00:00.908440 time to complete
# step 24 is completed! and taken 0:00:00.927748 time to complete
# step 25 is completed! and taken 0:00:01.648287 time to complete
# step 26 is completed! and taken 0:00:00.994593 time to complete
# step 27 is completed! and taken 0:00:01.014938 time to complete
# step 28 is completed! and taken 0:00:00.981334 time to complete
# step 29 is completed! and taken 0:00:01.293812 time to complete
# step 30 is completed! and taken 0:00:01.100299 time to complete
# step 31 is completed! and taken 0:00:01.133345 time to complete
# step 32 is completed! and taken 0:00:00.922566 time to complete
# step 33 is completed! and taken 0:00:00.917936 time to complete
# step 34 is completed! and taken 0:00:01.039620 time to complete
# step 35 is completed! and taken 0:00:00.875289 time to complete
# step 36 is completed! and taken 0:00:01.076852 time to complete
# step 37 is completed! and taken 0:00:01.091044 time to complete
# step 38 is completed! and taken 0:00:00.900446 time to complete
# step 39 is completed! and taken 0:00:01.548304 time to complete
# step 40 is completed! and taken 0:00:00.969819 time to complete
# step 41 is completed! and taken 0:00:01.331911 time to complete
# step 42 is completed! and taken 0:00:01.060428 time to complete
# step 43 is completed! and taken 0:00:00.907639 time to complete
# step 44 is completed! and taken 0:00:01.075316 time to complete
# step 45 is completed! and taken 0:00:00.999098 time to complete
# step 46 is completed! and taken 0:00:00.992362 time to complete
# step 47 is completed! and taken 0:00:01.045299 time to complete
# step 48 is completed! and taken 0:00:01.171058 time to complete
# step 49 is completed! and taken 0:00:01.183450 time to complete
# step 50 is completed! and taken 0:00:00.965625 time to complete
# step 51 is completed! and taken 0:00:01.020065 time to complete
# step 52 is completed! and taken 0:00:00.905741 time to complete
# step 53 is completed! and taken 0:00:01.144555 time to complete
# step 54 is completed! and taken 0:00:01.102695 time to complete
# step 55 is completed! and taken 0:00:01.027429 time to complete
# step 56 is completed! and taken 0:00:00.966935 time to complete
# step 57 is completed! and taken 0:00:00.958900 time to complete
# step 58 is completed! and taken 0:00:00.963261 time to complete
# step 59 is completed! and taken 0:00:00.921411 time to complete
# step 60 is completed! and taken 0:00:01.383395 time to complete
# step 61 is completed! and taken 0:00:00.991564 time to complete
# step 62 is completed! and taken 0:00:01.098511 time to complete
# step 63 is completed! and taken 0:00:01.219670 time to complete
# step 64 is completed! and taken 0:00:01.343484 time to complete
# step 65 is completed! and taken 0:00:00.946147 time to complete
# step 66 is completed! and taken 0:00:01.181610 time to complete
# step 67 is completed! and taken 0:00:00.928374 time to complete
# step 68 is completed! and taken 0:00:01.071458 time to complete
# step 69 is completed! and taken 0:00:01.014646 time to complete
# step 70 is completed! and taken 0:00:01.295603 time to complete
# step 71 is completed! and taken 0:00:00.962520 time to complete
# step 72 is completed! and taken 0:00:01.098633 time to complete
# step 73 is completed! and taken 0:00:01.171875 time to complete
# step 74 is completed! and taken 0:00:01.343518 time to complete
# step 75 is completed! and taken 0:00:01.128700 time to complete
# step 76 is completed! and taken 0:00:01.132718 time to complete
# step 77 is completed! and taken 0:00:00.942016 time to complete
# step 78 is completed! and taken 0:00:01.357145 time to complete
# step 79 is completed! and taken 0:00:01.075292 time to complete
# step 80 is completed! and taken 0:00:00.917687 time to complete
# step 81 is completed! and taken 0:00:01.131410 time to complete
# step 82 is completed! and taken 0:00:00.937375 time to complete
# step 83 is completed! and taken 0:00:00.937239 time to complete
# step 84 is completed! and taken 0:00:01.110159 time to complete
# step 85 is completed! and taken 0:00:00.987898 time to complete
# step 86 is completed! and taken 0:00:01.122067 time to complete
# step 87 is completed! and taken 0:00:01.098982 time to complete
# step 88 is completed! and taken 0:00:00.867274 time to complete
# step 89 is completed! and taken 0:00:01.136593 time to complete
# step 90 is completed! and taken 0:00:01.075430 time to complete
# step 91 is completed! and taken 0:00:01.143721 time to complete
# step 92 is completed! and taken 0:00:01.322656 time to complete
# step 93 is completed! and taken 0:00:01.025507 time to complete
# step 94 is completed! and taken 0:00:01.407217 time to complete
# step 95 is completed! and taken 0:00:01.174873 time to complete
# step 96 is completed! and taken 0:00:01.151125 time to complete
# step 97 is completed! and taken 0:00:01.158106 time to complete
# step 98 is completed! and taken 0:00:01.129507 time to complete
# step 99 is completed! and taken 0:00:01.118026 time to complete
# step 100 is completed! and taken 0:00:01.092456 time to complete
# step 101 is completed! and taken 0:00:01.088104 time to complete
# step 102 is completed! and taken 0:00:01.358774 time to complete
# step 103 is completed! and taken 0:00:00.943515 time to complete
# step 104 is completed! and taken 0:00:00.943468 time to complete
# step 105 is completed! and taken 0:00:00.902325 time to complete
# step 106 is completed! and taken 0:00:01.044020 time to complete
# step 107 is completed! and taken 0:00:01.079595 time to complete
# step 108 is completed! and taken 0:00:01.118736 time to complete
# step 109 is completed! and taken 0:00:01.470665 time to complete
# step 110 is completed! and taken 0:00:01.111394 time to complete
# step 111 is completed! and taken 0:00:01.018455 time to complete
# step 112 is completed! and taken 0:00:00.989863 time to complete
# step 113 is completed! and taken 0:00:00.938251 time to complete
# step 114 is completed! and taken 0:00:01.110238 time to complete
# step 115 is completed! and taken 0:00:00.992745 time to complete
# step 116 is completed! and taken 0:00:01.013708 time to complete
# step 117 is completed! and taken 0:00:01.213990 time to complete
# step 118 is completed! and taken 0:00:01.347018 time to complete
# step 119 is completed! and taken 0:00:01.039079 time to complete
# step 120 is completed! and taken 0:00:01.236677 time to complete
# step 121 is completed! and taken 0:00:01.297241 time to complete
# step 122 is completed! and taken 0:00:01.090462 time to complete
# step 123 is completed! and taken 0:00:01.036966 time to complete
# step 124 is completed! and taken 0:00:00.974637 time to complete
# step 125 is completed! and taken 0:00:01.159762 time to complete
# step 126 is completed! and taken 0:00:01.030775 time to complete
# step 127 is completed! and taken 0:00:01.130505 time to complete
# step 128 is completed! and taken 0:00:01.025166 time to complete
# step 129 is completed! and taken 0:00:00.933689 time to complete
# step 130 is completed! and taken 0:00:01.133998 time to complete
# step 131 is completed! and taken 0:00:01.093928 time to complete
# step 132 is completed! and taken 0:00:01.152028 time to complete
# step 133 is completed! and taken 0:00:01.075908 time to complete
# step 134 is completed! and taken 0:00:01.063523 time to complete
# step 135 is completed! and taken 0:00:00.985766 time to complete
# step 136 is completed! and taken 0:00:00.946049 time to complete
# step 137 is completed! and taken 0:00:01.099156 time to complete
# step 138 is completed! and taken 0:00:00.926182 time to complete
# step 139 is completed! and taken 0:00:00.972084 time to complete
# step 140 is completed! and taken 0:00:01.039760 time to complete
# step 141 is completed! and taken 0:00:01.174757 time to complete
# step 142 is completed! and taken 0:00:00.986239 time to complete
# step 143 is completed! and taken 0:00:01.006441 time to complete
# step 144 is completed! and taken 0:00:01.159130 time to complete
# step 145 is completed! and taken 0:00:00.997278 time to complete
# step 146 is completed! and taken 0:00:01.344944 time to complete
# step 147 is completed! and taken 0:00:01.913931 time to complete
# step 148 is completed! and taken 0:00:01.351596 time to complete
# step 149 is completed! and taken 0:00:01.434181 time to complete
# step 150 is completed! and taken 0:00:00.986354 time to complete
# step 151 is completed! and taken 0:00:01.320446 time to complete
# step 152 is completed! and taken 0:00:00.991289 time to complete
# step 153 is completed! and taken 0:00:01.317476 time to complete
# step 154 is completed! and taken 0:00:01.058220 time to complete
# step 155 is completed! and taken 0:00:01.052395 time to complete
# step 156 is completed! and taken 0:00:01.126388 time to complete
# step 157 is completed! and taken 0:00:01.007550 time to complete
# step 158 is completed! and taken 0:00:00.975311 time to complete
# step 159 is completed! and taken 0:00:01.071319 time to complete
# step 160 is completed! and taken 0:00:01.054177 time to complete
# step 161 is completed! and taken 0:00:01.066376 time to complete
# step 162 is completed! and taken 0:00:01.461193 time to complete
# step 163 is completed! and taken 0:00:00.987179 time to complete
# step 164 is completed! and taken 0:00:01.421825 time to complete
# step 165 is completed! and taken 0:00:01.084367 time to complete
# step 166 is completed! and taken 0:00:01.845154 time to complete
# step 167 is completed! and taken 0:00:01.912183 time to complete
# step 168 is completed! and taken 0:00:01.232756 time to complete
# step 169 is completed! and taken 0:00:02.193773 time to complete
# step 170 is completed! and taken 0:00:01.534044 time to complete
# step 171 is completed! and taken 0:00:00.967180 time to complete
# step 172 is completed! and taken 0:00:01.364857 time to complete
# step 173 is completed! and taken 0:00:02.362984 time to complete
# step 174 is completed! and taken 0:00:01.480178 time to complete
# step 175 is completed! and taken 0:00:00.987210 time to complete
# step 176 is completed! and taken 0:00:00.944520 time to complete
# step 177 is completed! and taken 0:00:01.476295 time to complete
# step 178 is completed! and taken 0:00:00.952528 time to complete
# step 179 is completed! and taken 0:00:01.229195 time to complete
# step 180 is completed! and taken 0:00:01.078300 time to complete
# step 181 is completed! and taken 0:00:00.962273 time to complete
# step 182 is completed! and taken 0:00:00.924634 time to complete
# step 183 is completed! and taken 0:00:00.961994 time to complete
# step 184 is completed! and taken 0:00:00.951684 time to complete
# step 185 is completed! and taken 0:00:01.113647 time to complete
# step 186 is completed! and taken 0:00:01.058855 time to complete
# step 187 is completed! and taken 0:00:00.985588 time to complete
# step 188 is completed! and taken 0:00:00.951477 time to complete
# step 189 is completed! and taken 0:00:00.882733 time to complete
# step 190 is completed! and taken 0:00:01.094032 time to complete
# step 191 is completed! and taken 0:00:00.999982 time to complete
# step 192 is completed! and taken 0:00:01.217096 time to complete
# step 193 is completed! and taken 0:00:01.155758 time to complete
# step 194 is completed! and taken 0:00:01.074895 time to complete
# step 195 is completed! and taken 0:00:01.024620 time to complete
# step 196 is completed! and taken 0:00:01.040699 time to complete
# step 197 is completed! and taken 0:00:00.945978 time to complete
# step 198 is completed! and taken 0:00:01.066497 time to complete
# step 199 is completed! and taken 0:00:01.111285 time to complete
# step 200 is completed! and taken 0:00:00.924318 time to complete
# step 201 is completed! and taken 0:00:00.944095 time to complete
# step 202 is completed! and taken 0:00:01.870860 time to complete
# step 203 is completed! and taken 0:00:01.628376 time to complete
# step 204 is completed! and taken 0:00:01.192966 time to complete
# step 205 is completed! and taken 0:00:00.885557 time to complete
# step 206 is completed! and taken 0:00:00.973811 time to complete
# step 207 is completed! and taken 0:00:01.151648 time to complete
# step 208 is completed! and taken 0:00:00.912816 time to complete
# step 209 is completed! and taken 0:00:01.439431 time to complete
# step 210 is completed! and taken 0:00:00.970148 time to complete
# step 211 is completed! and taken 0:00:01.080227 time to complete
# step 212 is completed! and taken 0:00:01.241043 time to complete
# step 213 is completed! and taken 0:00:01.098276 time to complete
# step 214 is completed! and taken 0:00:01.392338 time to complete
# step 215 is completed! and taken 0:00:01.113157 time to complete
# step 216 is completed! and taken 0:00:00.934930 time to complete
# step 217 is completed! and taken 0:00:01.154739 time to complete
# step 218 is completed! and taken 0:00:01.020064 time to complete
# step 219 is completed! and taken 0:00:01.453534 time to complete
# step 220 is completed! and taken 0:00:00.980205 time to complete
# step 221 is completed! and taken 0:00:01.188303 time to complete
# step 222 is completed! and taken 0:00:01.723372 time to complete
# step 223 is completed! and taken 0:00:00.979306 time to complete
# step 224 is completed! and taken 0:00:02.012307 time to complete
# step 225 is completed! and taken 0:00:00.930133 time to complete
# step 226 is completed! and taken 0:00:01.069433 time to complete
# step 227 is completed! and taken 0:00:01.701401 time to complete
# step 228 is completed! and taken 0:00:01.019441 time to complete
# step 229 is completed! and taken 0:00:00.948423 time to complete
# step 230 is completed! and taken 0:00:00.954933 time to complete
# step 231 is completed! and taken 0:00:01.119299 time to complete
# step 232 is completed! and taken 0:00:00.966076 time to complete
# step 233 is completed! and taken 0:00:00.901205 time to complete
# step 234 is completed! and taken 0:00:01.357702 time to complete
# step 235 is completed! and taken 0:00:01.173262 time to complete
# step 236 is completed! and taken 0:00:01.098246 time to complete
# step 237 is completed! and taken 0:00:01.030275 time to complete
# step 238 is completed! and taken 0:00:00.963163 time to complete
# step 239 is completed! and taken 0:00:00.970441 time to complete
# step 240 is completed! and taken 0:00:00.869442 time to complete
# step 241 is completed! and taken 0:00:01.036655 time to complete
# step 242 is completed! and taken 0:00:01.097010 time to complete
# step 243 is completed! and taken 0:00:00.897075 time to complete
# step 244 is completed! and taken 0:00:01.070794 time to complete
# step 245 is completed! and taken 0:00:01.046184 time to complete
# step 246 is completed! and taken 0:00:00.999459 time to complete
# step 247 is completed! and taken 0:00:00.908710 time to complete
# step 248 is completed! and taken 0:00:00.854840 time to complete
# step 249 is completed! and taken 0:00:01.027166 time to complete
# step 250 is completed! and taken 0:00:00.950648 time to complete
# step 251 is completed! and taken 0:00:00.986401 time to complete
# step 252 is completed! and taken 0:00:00.890880 time to complete
# step 253 is completed! and taken 0:00:01.239052 time to complete
# step 254 is completed! and taken 0:00:01.062952 time to complete
# step 255 is completed! and taken 0:00:01.184736 time to complete
# step 256 is completed! and taken 0:00:00.949347 time to complete
# step 257 is completed! and taken 0:00:00.864491 time to complete
# step 258 is completed! and taken 0:00:01.027042 time to complete
# step 259 is completed! and taken 0:00:01.687210 time to complete
# step 260 is completed! and taken 0:00:00.934386 time to complete
# step 261 is completed! and taken 0:00:00.922092 time to complete
# step 262 is completed! and taken 0:00:01.024076 time to complete
# step 263 is completed! and taken 0:00:01.059927 time to complete
# step 264 is completed! and taken 0:00:00.906525 time to complete
# step 265 is completed! and taken 0:00:01.468411 time to complete
# step 266 is completed! and taken 0:00:01.239129 time to complete
# step 267 is completed! and taken 0:00:00.981516 time to complete
# step 268 is completed! and taken 0:00:00.878091 time to complete
# step 269 is completed! and taken 0:00:00.922822 time to complete
# step 270 is completed! and taken 0:00:01.292140 time to complete
# step 271 is completed! and taken 0:00:01.061801 time to complete
# step 272 is completed! and taken 0:00:00.854710 time to complete
# step 273 is completed! and taken 0:00:01.045278 time to complete
# step 274 is completed! and taken 0:00:00.932819 time to complete
# step 275 is completed! and taken 0:00:00.968186 time to complete
# step 276 is completed! and taken 0:00:00.894835 time to complete
# step 277 is completed! and taken 0:00:01.130886 time to complete
# step 278 is completed! and taken 0:00:01.030661 time to complete
# step 279 is completed! and taken 0:00:01.027533 time to complete
# step 280 is completed! and taken 0:00:00.892576 time to complete
# step 281 is completed! and taken 0:00:00.976778 time to complete
# step 282 is completed! and taken 0:00:00.988661 time to complete
# step 283 is completed! and taken 0:00:01.110333 time to complete
# step 284 is completed! and taken 0:00:00.989734 time to complete
# step 285 is completed! and taken 0:00:00.882825 time to complete
# step 286 is completed! and taken 0:00:00.888855 time to complete
# step 287 is completed! and taken 0:00:01.218948 time to complete
# step 288 is completed! and taken 0:00:01.318347 time to complete
# step 289 is completed! and taken 0:00:01.112843 time to complete
# step 290 is completed! and taken 0:00:01.068021 time to complete
# step 291 is completed! and taken 0:00:01.001873 time to complete
# step 292 is completed! and taken 0:00:00.954449 time to complete
# step 293 is completed! and taken 0:00:01.121656 time to complete
# step 294 is completed! and taken 0:00:00.969741 time to complete
# step 295 is completed! and taken 0:00:01.086683 time to complete
# step 296 is completed! and taken 0:00:01.058729 time to complete
# step 297 is completed! and taken 0:00:01.108226 time to complete
# step 298 is completed! and taken 0:00:00.991330 time to complete
# step 299 is completed! and taken 0:00:01.017807 time to complete
# step 300 is completed! and taken 0:00:01.209390 time to complete
# step 301 is completed! and taken 0:00:01.025629 time to complete
# step 302 is completed! and taken 0:00:01.161084 time to complete
# step 303 is completed! and taken 0:00:00.943987 time to complete
# step 304 is completed! and taken 0:00:00.918264 time to complete
# step 305 is completed! and taken 0:00:00.932211 time to complete
# step 306 is completed! and taken 0:00:01.148468 time to complete
# step 307 is completed! and taken 0:00:01.081616 time to complete
# step 308 is completed! and taken 0:00:00.884333 time to complete
# step 309 is completed! and taken 0:00:00.914588 time to complete
# step 310 is completed! and taken 0:00:01.190294 time to complete
# step 311 is completed! and taken 0:00:00.938551 time to complete
# step 312 is completed! and taken 0:00:00.998581 time to complete
# step 313 is completed! and taken 0:00:01.233857 time to complete
# step 314 is completed! and taken 0:00:01.052086 time to complete
# step 315 is completed! and taken 0:00:01.132655 time to complete
# step 316 is completed! and taken 0:00:01.070921 time to complete
# step 317 is completed! and taken 0:00:00.967211 time to complete
# step 318 is completed! and taken 0:00:01.030883 time to complete
# step 319 is completed! and taken 0:00:01.063013 time to complete
# step 320 is completed! and taken 0:00:01.054164 time to complete
# step 321 is completed! and taken 0:00:01.221918 time to complete
# step 322 is completed! and taken 0:00:01.111748 time to complete
# step 323 is completed! and taken 0:00:00.951281 time to complete
# step 324 is completed! and taken 0:00:01.023155 time to complete
# step 325 is completed! and taken 0:00:01.060200 time to complete
# step 326 is completed! and taken 0:00:01.219310 time to complete
# step 327 is completed! and taken 0:00:01.254544 time to complete
# step 328 is completed! and taken 0:00:01.004982 time to complete
# step 329 is completed! and taken 0:00:01.135971 time to complete
# step 330 is completed! and taken 0:00:01.230995 time to complete
# step 331 is completed! and taken 0:00:01.277841 time to complete
# step 332 is completed! and taken 0:00:01.051999 time to complete
# step 333 is completed! and taken 0:00:02.022987 time to complete
# step 334 is completed! and taken 0:00:01.189194 time to complete
# step 335 is completed! and taken 0:00:01.005078 time to complete
# step 336 is completed! and taken 0:00:01.529384 time to complete
# step 337 is completed! and taken 0:00:01.410660 time to complete
# step 338 is completed! and taken 0:00:01.410343 time to complete
# step 339 is completed! and taken 0:00:01.225880 time to complete
# step 340 is completed! and taken 0:00:01.235098 time to complete
# step 341 is completed! and taken 0:00:01.025146 time to complete
# step 342 is completed! and taken 0:00:00.994663 time to complete
# step 343 is completed! and taken 0:00:00.918576 time to complete
# step 344 is completed! and taken 0:00:01.010537 time to complete
# step 345 is completed! and taken 0:00:01.199233 time to complete
# step 346 is completed! and taken 0:00:00.928216 time to complete
# step 347 is completed! and taken 0:00:00.876279 time to complete
# step 348 is completed! and taken 0:00:01.175168 time to complete
# step 349 is completed! and taken 0:00:01.018096 time to complete
# step 350 is completed! and taken 0:00:01.035677 time to complete
# step 351 is completed! and taken 0:00:01.001937 time to complete
# step 352 is completed! and taken 0:00:00.934451 time to complete
# step 353 is completed! and taken 0:00:00.943290 time to complete
# step 354 is completed! and taken 0:00:00.945440 time to complete
# step 355 is completed! and taken 0:00:01.793117 time to complete
# step 356 is completed! and taken 0:00:01.610207 time to complete
# step 357 is completed! and taken 0:00:01.154109 time to complete
# step 358 is completed! and taken 0:00:01.023429 time to complete
# step 359 is completed! and taken 0:00:01.202867 time to complete
# step 360 is completed! and taken 0:00:01.084099 time to complete
# step 361 is completed! and taken 0:00:01.393310 time to complete
# step 362 is completed! and taken 0:00:01.466297 time to complete
# step 363 is completed! and taken 0:00:01.356205 time to complete
# step 364 is completed! and taken 0:00:01.424997 time to complete
# step 365 is completed! and taken 0:00:00.923475 time to complete
# step 366 is completed! and taken 0:00:00.889401 time to complete
# step 367 is completed! and taken 0:00:01.281532 time to complete
# step 368 is completed! and taken 0:00:01.079627 time to complete
# step 369 is completed! and taken 0:00:01.149158 time to complete
# step 370 is completed! and taken 0:00:00.941493 time to complete
# step 371 is completed! and taken 0:00:00.865446 time to complete
# step 372 is completed! and taken 0:00:01.115157 time to complete
# step 373 is completed! and taken 0:00:00.844219 time to complete
# step 374 is completed! and taken 0:00:01.215506 time to complete
# step 375 is completed! and taken 0:00:00.993850 time to complete
# step 376 is completed! and taken 0:00:01.178487 time to complete
# step 377 is completed! and taken 0:00:00.886584 time to complete
# step 378 is completed! and taken 0:00:01.115689 time to complete
# step 379 is completed! and taken 0:00:01.052773 time to complete
# step 380 is completed! and taken 0:00:00.938860 time to complete
# step 381 is completed! and taken 0:00:01.018924 time to complete
# step 382 is completed! and taken 0:00:01.030750 time to complete
# step 383 is completed! and taken 0:00:01.529038 time to complete
# step 384 is completed! and taken 0:00:01.056720 time to complete
# step 385 is completed! and taken 0:00:01.045661 time to complete
# step 386 is completed! and taken 0:00:01.054178 time to complete
# step 387 is completed! and taken 0:00:01.017138 time to complete
# step 388 is completed! and taken 0:00:01.077030 time to complete
# step 389 is completed! and taken 0:00:00.936328 time to complete
# step 390 is completed! and taken 0:00:01.037917 time to complete
# step 391 is completed! and taken 0:00:01.049297 time to complete
# step 392 is completed! and taken 0:00:00.937828 time to complete
# step 393 is completed! and taken 0:00:01.341605 time to complete
# step 394 is completed! and taken 0:00:00.982848 time to complete
# step 395 is completed! and taken 0:00:01.049800 time to complete
# step 396 is completed! and taken 0:00:00.968365 time to complete
# step 397 is completed! and taken 0:00:01.015164 time to complete
# step 398 is completed! and taken 0:00:00.919804 time to complete
# step 399 is completed! and taken 0:00:01.412176 time to complete
# step 400 is completed! and taken 0:00:00.910590 time to complete
# step 401 is completed! and taken 0:00:01.592579 time to complete
# step 402 is completed! and taken 0:00:01.364807 time to complete
# step 403 is completed! and taken 0:00:01.212611 time to complete
# step 404 is completed! and taken 0:00:00.952322 time to complete
# step 405 is completed! and taken 0:00:01.159391 time to complete
# step 406 is completed! and taken 0:00:01.144816 time to complete
# step 407 is completed! and taken 0:00:00.994326 time to complete
# step 408 is completed! and taken 0:00:00.882778 time to complete
# step 409 is completed! and taken 0:00:00.891613 time to complete
# step 410 is completed! and taken 0:00:00.901639 time to complete
# step 411 is completed! and taken 0:00:01.018044 time to complete
# step 412 is completed! and taken 0:00:01.129756 time to complete
# step 413 is completed! and taken 0:00:01.175709 time to complete
# step 414 is completed! and taken 0:00:00.960644 time to complete
# step 415 is completed! and taken 0:00:01.137792 time to complete
# step 416 is completed! and taken 0:00:01.070790 time to complete
# step 417 is completed! and taken 0:00:00.909636 time to complete
# step 418 is completed! and taken 0:00:00.982790 time to complete
# step 419 is completed! and taken 0:00:00.994412 time to complete
# step 420 is completed! and taken 0:00:00.960895 time to complete
# step 421 is completed! and taken 0:00:00.955656 time to complete
# step 422 is completed! and taken 0:00:00.914812 time to complete
# step 423 is completed! and taken 0:00:01.049730 time to complete
# step 424 is completed! and taken 0:00:00.931818 time to complete
# step 425 is completed! and taken 0:00:01.030083 time to complete
# step 426 is completed! and taken 0:00:00.933944 time to complete
# step 427 is completed! and taken 0:00:01.107718 time to complete
# step 428 is completed! and taken 0:00:00.989917 time to complete
# step 429 is completed! and taken 0:00:01.202108 time to complete
# step 430 is completed! and taken 0:00:01.021850 time to complete
# step 431 is completed! and taken 0:00:00.921897 time to complete
# step 432 is completed! and taken 0:00:00.951669 time to complete
# step 433 is completed! and taken 0:00:00.958045 time to complete
# step 434 is completed! and taken 0:00:00.931008 time to complete
# step 435 is completed! and taken 0:00:01.121776 time to complete
# step 436 is completed! and taken 0:00:00.966365 time to complete
# step 437 is completed! and taken 0:00:01.002060 time to complete
# step 438 is completed! and taken 0:00:00.942949 time to complete
# step 439 is completed! and taken 0:00:00.977360 time to complete
# step 440 is completed! and taken 0:00:01.162736 time to complete
# step 441 is completed! and taken 0:00:00.988122 time to complete
# step 442 is completed! and taken 0:00:00.958096 time to complete
# step 443 is completed! and taken 0:00:00.941972 time to complete
# step 444 is completed! and taken 0:00:01.215622 time to complete
# step 445 is completed! and taken 0:00:01.020144 time to complete
# step 446 is completed! and taken 0:00:00.943924 time to complete
# step 447 is completed! and taken 0:00:00.927247 time to complete
# step 448 is completed! and taken 0:00:00.941441 time to complete
# step 449 is completed! and taken 0:00:01.049252 time to complete
# step 450 is completed! and taken 0:00:01.451829 time to complete
# step 451 is completed! and taken 0:00:01.127421 time to complete
# step 452 is completed! and taken 0:00:00.914001 time to complete
# step 453 is completed! and taken 0:00:01.049319 time to complete
# step 454 is completed! and taken 0:00:00.930945 time to complete
# step 455 is completed! and taken 0:00:00.869504 time to complete
# step 456 is completed! and taken 0:00:01.011028 time to complete
# step 457 is completed! and taken 0:00:01.045549 time to complete
# step 458 is completed! and taken 0:00:00.942358 time to complete
# step 459 is completed! and taken 0:00:01.053581 time to complete
# step 460 is completed! and taken 0:00:01.034561 time to complete
# step 461 is completed! and taken 0:00:00.921420 time to complete
# step 462 is completed! and taken 0:00:01.058496 time to complete
# step 463 is completed! and taken 0:00:00.925796 time to complete
# step 464 is completed! and taken 0:00:01.022156 time to complete
# step 465 is completed! and taken 0:00:01.042275 time to complete
# step 466 is completed! and taken 0:00:01.010560 time to complete
# step 467 is completed! and taken 0:00:01.016638 time to complete
# step 468 is completed! and taken 0:00:01.078276 time to complete
# step 469 is completed! and taken 0:00:00.940968 time to complete
# step 470 is completed! and taken 0:00:01.024442 time to complete
# step 471 is completed! and taken 0:00:01.042671 time to complete
# step 472 is completed! and taken 0:00:01.027194 time to complete
# step 473 is completed! and taken 0:00:00.948646 time to complete
# step 474 is completed! and taken 0:00:01.177386 time to complete
# step 475 is completed! and taken 0:00:00.985815 time to complete
# step 476 is completed! and taken 0:00:00.877956 time to complete
# step 477 is completed! and taken 0:00:00.870516 time to complete
# step 478 is completed! and taken 0:00:01.162679 time to complete
# step 479 is completed! and taken 0:00:00.955497 time to complete
# step 480 is completed! and taken 0:00:00.951486 time to complete
# step 481 is completed! and taken 0:00:01.231031 time to complete
# step 482 is completed! and taken 0:00:00.937921 time to complete
# step 483 is completed! and taken 0:00:01.021023 time to complete
# step 484 is completed! and taken 0:00:00.949470 time to complete
# step 485 is completed! and taken 0:00:01.005076 time to complete
# step 486 is completed! and taken 0:00:01.003519 time to complete
# step 487 is completed! and taken 0:00:01.171357 time to complete
# step 488 is completed! and taken 0:00:00.884870 time to complete
# step 489 is completed! and taken 0:00:00.883960 time to complete
# step 490 is completed! and taken 0:00:00.992470 time to complete
# step 491 is completed! and taken 0:00:01.032321 time to complete
# step 492 is completed! and taken 0:00:00.905121 time to complete
# step 493 is completed! and taken 0:00:01.049894 time to complete
# step 494 is completed! and taken 0:00:01.038111 time to complete
# step 495 is completed! and taken 0:00:00.964658 time to complete
# step 496 is completed! and taken 0:00:01.068518 time to complete
# step 497 is completed! and taken 0:00:00.980717 time to complete
# step 498 is completed! and taken 0:00:01.036257 time to complete
# step 499 is completed! and taken 0:00:01.193470 time to complete
# step 500 is completed! and taken 0:00:00.958271 time to complete
# step 501 is completed! and taken 0:00:00.949892 time to complete
# step 502 is completed! and taken 0:00:00.910184 time to complete
# step 503 is completed! and taken 0:00:00.970347 time to complete
# step 504 is completed! and taken 0:00:01.053898 time to complete
# step 505 is completed! and taken 0:00:00.950789 time to complete
# step 506 is completed! and taken 0:00:00.976598 time to complete
# step 507 is completed! and taken 0:00:01.014035 time to complete
# step 508 is completed! and taken 0:00:00.937928 time to complete
# step 509 is completed! and taken 0:00:00.997418 time to complete
# step 510 is completed! and taken 0:00:00.970535 time to complete
# step 511 is completed! and taken 0:00:02.995373 time to complete
# step 512 is completed! and taken 0:00:01.280529 time to complete
# step 513 is completed! and taken 0:00:01.620611 time to complete
# step 514 is completed! and taken 0:00:01.217542 time to complete
# step 515 is completed! and taken 0:00:01.578106 time to complete
# step 516 is completed! and taken 0:00:01.178793 time to complete
# step 517 is completed! and taken 0:00:01.659150 time to complete
# step 518 is completed! and taken 0:00:01.020457 time to complete
# step 519 is completed! and taken 0:00:01.195992 time to complete
# step 520 is completed! and taken 0:00:01.411943 time to complete
# step 521 is completed! and taken 0:00:01.237136 time to complete
# step 522 is completed! and taken 0:00:01.213105 time to complete
# step 523 is completed! and taken 0:00:01.130800 time to complete
# step 524 is completed! and taken 0:00:01.159724 time to complete
# step 525 is completed! and taken 0:00:00.972675 time to complete
# step 526 is completed! and taken 0:00:00.949921 time to complete
# step 527 is completed! and taken 0:00:00.871317 time to complete
# step 528 is completed! and taken 0:00:01.213630 time to complete
# step 529 is completed! and taken 0:00:01.134459 time to complete
# step 530 is completed! and taken 0:00:00.913664 time to complete
# step 531 is completed! and taken 0:00:01.023780 time to complete
# step 532 is completed! and taken 0:00:00.984297 time to complete
# step 533 is completed! and taken 0:00:00.966673 time to complete
# step 534 is completed! and taken 0:00:00.983564 time to complete
# step 535 is completed! and taken 0:00:00.951869 time to complete
# step 536 is completed! and taken 0:00:01.005022 time to complete
# step 537 is completed! and taken 0:00:01.167964 time to complete
# step 538 is completed! and taken 0:00:01.371367 time to complete
# step 539 is completed! and taken 0:00:01.640251 time to complete
# step 540 is completed! and taken 0:00:01.039593 time to complete
# step 541 is completed! and taken 0:00:00.912028 time to complete
# step 542 is completed! and taken 0:00:01.062627 time to complete
# step 543 is completed! and taken 0:00:01.001990 time to complete
# step 544 is completed! and taken 0:00:00.957736 time to complete
# step 545 is completed! and taken 0:00:01.017400 time to complete
# step 546 is completed! and taken 0:00:01.045136 time to complete
# step 547 is completed! and taken 0:00:00.993874 time to complete
# step 548 is completed! and taken 0:00:00.983859 time to complete
# step 549 is completed! and taken 0:00:00.922182 time to complete
# step 550 is completed! and taken 0:00:01.153766 time to complete
# step 551 is completed! and taken 0:00:01.407859 time to complete
# step 552 is completed! and taken 0:00:01.260904 time to complete
# step 553 is completed! and taken 0:00:01.126068 time to complete
# step 554 is completed! and taken 0:00:00.922405 time to complete
# step 555 is completed! and taken 0:00:01.190964 time to complete
# step 556 is completed! and taken 0:00:00.988287 time to complete
# step 557 is completed! and taken 0:00:00.893692 time to complete
# step 558 is completed! and taken 0:00:00.948082 time to complete
# step 559 is completed! and taken 0:00:01.068103 time to complete
# step 560 is completed! and taken 0:00:00.952903 time to complete
# step 561 is completed! and taken 0:00:01.023987 time to complete
# step 562 is completed! and taken 0:00:01.010197 time to complete
# step 563 is completed! and taken 0:00:01.103862 time to complete
# step 564 is completed! and taken 0:00:00.955648 time to complete
# step 565 is completed! and taken 0:00:00.911712 time to complete
# step 566 is completed! and taken 0:00:01.040136 time to complete
# step 567 is completed! and taken 0:00:01.652899 time to complete
# step 568 is completed! and taken 0:00:01.433699 time to complete
# step 569 is completed! and taken 0:00:00.920817 time to complete
# step 570 is completed! and taken 0:00:00.991662 time to complete
# step 571 is completed! and taken 0:00:01.028593 time to complete
# step 572 is completed! and taken 0:00:00.927793 time to complete
# step 573 is completed! and taken 0:00:01.131482 time to complete
# step 574 is completed! and taken 0:00:01.019547 time to complete
# step 575 is completed! and taken 0:00:00.996013 time to complete
# step 576 is completed! and taken 0:00:00.904536 time to complete
# step 577 is completed! and taken 0:00:00.906310 time to complete
# step 578 is completed! and taken 0:00:01.119681 time to complete
# step 579 is completed! and taken 0:00:01.008273 time to complete
# step 580 is completed! and taken 0:00:01.405432 time to complete
# step 581 is completed! and taken 0:00:00.990810 time to complete
# step 582 is completed! and taken 0:00:01.166007 time to complete
# step 583 is completed! and taken 0:00:01.057772 time to complete
# step 584 is completed! and taken 0:00:00.966394 time to complete
# step 585 is completed! and taken 0:00:01.015133 time to complete
# step 586 is completed! and taken 0:00:00.915300 time to complete
# step 587 is completed! and taken 0:00:00.975294 time to complete
# step 588 is completed! and taken 0:00:00.940811 time to complete
# step 589 is completed! and taken 0:00:01.061131 time to complete
# step 590 is completed! and taken 0:00:01.541135 time to complete
# step 591 is completed! and taken 0:00:01.250591 time to complete
# step 592 is completed! and taken 0:00:01.108659 time to complete
# step 593 is completed! and taken 0:00:01.114801 time to complete
# step 594 is completed! and taken 0:00:01.116645 time to complete
# step 595 is completed! and taken 0:00:01.161909 time to complete
# step 596 is completed! and taken 0:00:01.038892 time to complete
# step 597 is completed! and taken 0:00:00.927300 time to complete
# step 598 is completed! and taken 0:00:00.920342 time to complete
# step 599 is completed! and taken 0:00:01.013045 time to complete
# step 600 is completed! and taken 0:00:01.139544 time to complete
# step 601 is completed! and taken 0:00:01.022551 time to complete
# step 602 is completed! and taken 0:00:01.038469 time to complete
# step 603 is completed! and taken 0:00:01.049362 time to complete
# step 604 is completed! and taken 0:00:00.988134 time to complete
# step 605 is completed! and taken 0:00:00.976132 time to complete
# step 606 is completed! and taken 0:00:00.971194 time to complete
# step 607 is completed! and taken 0:00:01.075494 time to complete
# step 608 is completed! and taken 0:00:01.024444 time to complete
# step 609 is completed! and taken 0:00:01.079862 time to complete
# step 610 is completed! and taken 0:00:01.035686 time to complete
# step 611 is completed! and taken 0:00:01.022657 time to complete
# step 612 is completed! and taken 0:00:01.035709 time to complete
# step 613 is completed! and taken 0:00:01.010141 time to complete
# step 614 is completed! and taken 0:00:00.890337 time to complete
# step 615 is completed! and taken 0:00:01.044287 time to complete
# step 616 is completed! and taken 0:00:01.079058 time to complete
# step 617 is completed! and taken 0:00:00.966731 time to complete
# step 618 is completed! and taken 0:00:01.297732 time to complete
# step 619 is completed! and taken 0:00:01.459486 time to complete
# step 620 is completed! and taken 0:00:01.308035 time to complete
# step 621 is completed! and taken 0:00:01.040457 time to complete
# step 622 is completed! and taken 0:00:00.988782 time to complete
# step 623 is completed! and taken 0:00:01.214002 time to complete
# step 624 is completed! and taken 0:00:01.126302 time to complete
# step 625 is completed! and taken 0:00:01.268925 time to complete
# step 626 is completed! and taken 0:00:00.967123 time to complete
# step 627 is completed! and taken 0:00:00.949878 time to complete
# step 628 is completed! and taken 0:00:00.958968 time to complete
# step 629 is completed! and taken 0:00:01.039049 time to complete
# step 630 is completed! and taken 0:00:00.895582 time to complete
# step 631 is completed! and taken 0:00:01.073045 time to complete
# step 632 is completed! and taken 0:00:01.066435 time to complete
# step 633 is completed! and taken 0:00:00.946454 time to complete
# step 634 is completed! and taken 0:00:00.957005 time to complete
# step 635 is completed! and taken 0:00:01.128804 time to complete
# step 636 is completed! and taken 0:00:01.221699 time to complete
# step 637 is completed! and taken 0:00:00.971774 time to complete
# step 638 is completed! and taken 0:00:01.069512 time to complete
# step 639 is completed! and taken 0:00:01.031885 time to complete
# step 640 is completed! and taken 0:00:00.942812 time to complete
# step 641 is completed! and taken 0:00:01.064278 time to complete
# step 642 is completed! and taken 0:00:01.086435 time to complete
# step 643 is completed! and taken 0:00:01.012913 time to complete
# step 644 is completed! and taken 0:00:01.065454 time to complete
# step 645 is completed! and taken 0:00:00.882828 time to complete
# step 646 is completed! and taken 0:00:01.078637 time to complete
# step 647 is completed! and taken 0:00:01.327386 time to complete
# step 648 is completed! and taken 0:00:01.591292 time to complete
# step 649 is completed! and taken 0:00:01.235316 time to complete
# step 650 is completed! and taken 0:00:01.000945 time to complete
# step 651 is completed! and taken 0:00:01.040985 time to complete
# step 652 is completed! and taken 0:00:01.043823 time to complete
# step 653 is completed! and taken 0:00:01.006508 time to complete
# step 654 is completed! and taken 0:00:00.996043 time to complete
# step 655 is completed! and taken 0:00:00.918775 time to complete
# step 656 is completed! and taken 0:00:01.004518 time to complete
# step 657 is completed! and taken 0:00:00.943030 time to complete
# step 658 is completed! and taken 0:00:00.911374 time to complete
# step 659 is completed! and taken 0:00:00.897191 time to complete
# step 660 is completed! and taken 0:00:01.082905 time to complete
# step 661 is completed! and taken 0:00:01.293755 time to complete
# step 662 is completed! and taken 0:00:01.331868 time to complete
# step 663 is completed! and taken 0:00:00.971533 time to complete
# step 664 is completed! and taken 0:00:01.326955 time to complete
# step 665 is completed! and taken 0:00:01.256101 time to complete
# step 666 is completed! and taken 0:00:01.019957 time to complete
# step 667 is completed! and taken 0:00:01.294165 time to complete
# step 668 is completed! and taken 0:00:01.217448 time to complete
# step 669 is completed! and taken 0:00:01.212031 time to complete
# step 670 is completed! and taken 0:00:00.942764 time to complete
# step 671 is completed! and taken 0:00:01.127675 time to complete
# step 672 is completed! and taken 0:00:01.291103 time to complete
# step 673 is completed! and taken 0:00:01.013047 time to complete
# step 674 is completed! and taken 0:00:01.233652 time to complete
# step 675 is completed! and taken 0:00:00.953921 time to complete
# step 676 is completed! and taken 0:00:01.051912 time to complete
# step 677 is completed! and taken 0:00:00.907974 time to complete
# step 678 is completed! and taken 0:00:00.945538 time to complete
# step 679 is completed! and taken 0:00:01.081903 time to complete
# step 680 is completed! and taken 0:00:01.081291 time to complete
# step 681 is completed! and taken 0:00:00.943922 time to complete
# step 682 is completed! and taken 0:00:00.927307 time to complete
# step 683 is completed! and taken 0:00:01.137611 time to complete
# step 684 is completed! and taken 0:00:01.306125 time to complete
# step 685 is completed! and taken 0:00:00.945498 time to complete
# step 686 is completed! and taken 0:00:00.960144 time to complete
# step 687 is completed! and taken 0:00:00.947094 time to complete
# step 688 is completed! and taken 0:00:01.181890 time to complete
# step 689 is completed! and taken 0:00:00.950498 time to complete
# step 690 is completed! and taken 0:00:00.911250 time to complete
# step 691 is completed! and taken 0:00:00.988375 time to complete
# step 692 is completed! and taken 0:00:01.014848 time to complete
# step 693 is completed! and taken 0:00:01.144044 time to complete
# step 694 is completed! and taken 0:00:00.935381 time to complete
# step 695 is completed! and taken 0:00:00.946376 time to complete
# step 696 is completed! and taken 0:00:00.916800 time to complete
# step 697 is completed! and taken 0:00:00.942382 time to complete
# step 698 is completed! and taken 0:00:01.174272 time to complete
# step 699 is completed! and taken 0:00:00.958659 time to complete
# step 700 is completed! and taken 0:00:00.856042 time to complete
# step 701 is completed! and taken 0:00:00.961665 time to complete
# step 702 is completed! and taken 0:00:01.180374 time to complete
# step 703 is completed! and taken 0:00:01.019114 time to complete
# step 704 is completed! and taken 0:00:00.919750 time to complete
# step 705 is completed! and taken 0:00:01.043293 time to complete
# step 706 is completed! and taken 0:00:00.921734 time to complete
# step 707 is completed! and taken 0:00:01.021086 time to complete
# step 708 is completed! and taken 0:00:01.093636 time to complete
# step 709 is completed! and taken 0:00:00.942034 time to complete
# step 710 is completed! and taken 0:00:00.902436 time to complete
# step 711 is completed! and taken 0:00:01.138426 time to complete
# step 712 is completed! and taken 0:00:01.212395 time to complete
# step 713 is completed! and taken 0:00:01.149625 time to complete
# step 714 is completed! and taken 0:00:00.971715 time to complete
# step 715 is completed! and taken 0:00:00.919376 time to complete
# step 716 is completed! and taken 0:00:00.928880 time to complete
# step 717 is completed! and taken 0:00:00.932866 time to complete
# step 718 is completed! and taken 0:00:01.039328 time to complete
# step 719 is completed! and taken 0:00:00.940057 time to complete
# step 720 is completed! and taken 0:00:00.901721 time to complete
# step 721 is completed! and taken 0:00:01.089494 time to complete
# step 722 is completed! and taken 0:00:01.135001 time to complete
# step 723 is completed! and taken 0:00:00.947957 time to complete
# step 724 is completed! and taken 0:00:01.010425 time to complete
# step 725 is completed! and taken 0:00:00.877927 time to complete
# step 726 is completed! and taken 0:00:01.113269 time to complete
# step 727 is completed! and taken 0:00:01.074870 time to complete
# step 728 is completed! and taken 0:00:00.987433 time to complete
# step 729 is completed! and taken 0:00:00.886861 time to complete
# step 730 is completed! and taken 0:00:00.931851 time to complete
# step 731 is completed! and taken 0:00:01.183356 time to complete
# step 732 is completed! and taken 0:00:00.994493 time to complete
# step 733 is completed! and taken 0:00:00.923318 time to complete
# step 734 is completed! and taken 0:00:00.985725 time to complete
# step 735 is completed! and taken 0:00:01.200536 time to complete
# step 736 is completed! and taken 0:00:01.001349 time to complete
# step 737 is completed! and taken 0:00:00.955372 time to complete
# step 738 is completed! and taken 0:00:01.426339 time to complete
# step 739 is completed! and taken 0:00:01.027640 time to complete
# step 740 is completed! and taken 0:00:00.994496 time to complete
# ...
# step 746 is completed! and taken 0:00:00.892551 time to complete
# step 747 is completed! and taken 0:00:01.043751 time to complete
# step 748 is completed! and taken 0:00:00.991304 time to complete
# step 749 is completed! and taken 0:00:00.904016 time to complete
# step 750 is completed! and taken 0:00:01.036613 time to complete
# step 751 is completed! and taken 0:00:01.302348 time to complete
# step 752 is completed! and taken 0:00:01.018931 time to complete
# step 753 is completed! and taken 0:00:01.099894 time to complete
# step 754 is completed! and taken 0:00:00.973979 time to complete
# step 755 is completed! and taken 0:00:00.957104 time to complete
# step 756 is completed! and taken 0:00:00.949047 time to complete
# step 757 is completed! and taken 0:00:01.037226 time to complete
# step 758 is completed! and taken 0:00:00.877949 time to complete
# step 759 is completed! and taken 0:00:00.923758 time to complete
# step 760 is completed! and taken 0:00:00.910295 time to complete
# step 761 is completed! and taken 0:00:01.417860 time to complete
# step 762 is completed! and taken 0:00:01.217222 time to complete
# step 763 is completed! and taken 0:00:00.948565 time to complete
# step 764 is completed! and taken 0:00:01.026172 time to complete
# step 765 is completed! and taken 0:00:01.020648 time to complete
# step 766 is completed! and taken 0:00:00.993613 time to complete
# step 767 is completed! and taken 0:00:00.958557 time to complete
# step 768 is completed! and taken 0:00:01.560744 time to complete
# step 769 is completed! and taken 0:00:00.993725 time to complete
# step 770 is completed! and taken 0:00:00.975813 time to complete
# step 771 is completed! and taken 0:00:01.203509 time to complete
# step 772 is completed! and taken 0:00:00.950099 time to complete
# step 773 is completed! and taken 0:00:01.058757 time to complete
# step 774 is completed! and taken 0:00:00.921728 time to complete
# step 775 is completed! and taken 0:00:00.935391 time to complete
# step 776 is completed! and taken 0:00:00.932130 time to complete
# step 777 is completed! and taken 0:00:01.059351 time to complete
# step 778 is completed! and taken 0:00:00.941159 time to complete
# step 779 is completed! and taken 0:00:01.078173 time to complete
# step 780 is completed! and taken 0:00:01.035448 time to complete
# step 781 is completed! and taken 0:00:00.957833 time to complete
# step 782 is completed! and taken 0:00:00.942644 time to complete
# step 783 is completed! and taken 0:00:01.064758 time to complete
# step 784 is completed! and taken 0:00:01.144042 time to complete
# step 785 is completed! and taken 0:00:01.045080 time to complete
# step 786 is completed! and taken 0:00:01.176727 time to complete
# step 787 is completed! and taken 0:00:01.018114 time to complete
# step 788 is completed! and taken 0:00:01.147128 time to complete
# step 789 is completed! and taken 0:00:00.957920 time to complete
# step 790 is completed! and taken 0:00:01.242889 time to complete
# step 791 is completed! and taken 0:00:01.004010 time to complete
# step 792 is completed! and taken 0:00:01.066517 time to complete
# step 793 is completed! and taken 0:00:00.906248 time to complete
# step 794 is completed! and taken 0:00:00.979337 time to complete
# step 795 is completed! and taken 0:00:00.959155 time to complete
# step 796 is completed! and taken 0:00:00.919848 time to complete
# step 797 is completed! and taken 0:00:01.093688 time to complete
# step 798 is completed! and taken 0:00:01.124806 time to complete
# step 799 is completed! and taken 0:00:01.337074 time to complete
# step 800 is completed! and taken 0:00:01.022581 time to complete
# step 801 is completed! and taken 0:00:00.967567 time to complete
# step 802 is completed! and taken 0:00:00.987342 time to complete
# step 803 is completed! and taken 0:00:00.894675 time to complete
# step 804 is completed! and taken 0:00:01.081013 time to complete
# step 805 is completed! and taken 0:00:00.912756 time to complete
# step 806 is completed! and taken 0:00:01.126917 time to complete
# step 807 is completed! and taken 0:00:01.507920 time to complete
# step 808 is completed! and taken 0:00:00.920803 time to complete
# step 809 is completed! and taken 0:00:01.424297 time to complete
# step 810 is completed! and taken 0:00:01.071919 time to complete
# step 811 is completed! and taken 0:00:01.354011 time to complete
# step 812 is completed! and taken 0:00:01.156623 time to complete
# step 813 is completed! and taken 0:00:00.934982 time to complete
# step 814 is completed! and taken 0:00:01.392889 time to complete
# step 815 is completed! and taken 0:00:01.287710 time to complete
# step 816 is completed! and taken 0:00:01.017083 time to complete
# step 817 is completed! and taken 0:00:01.166765 time to complete
# step 818 is completed! and taken 0:00:00.959582 time to complete
# step 819 is completed! and taken 0:00:01.243239 time to complete
# step 820 is completed! and taken 0:00:00.926417 time to complete
# step 821 is completed! and taken 0:00:01.188767 time to complete
# step 822 is completed! and taken 0:00:02.008680 time to complete
# step 823 is completed! and taken 0:00:01.332704 time to complete
# step 824 is completed! and taken 0:00:01.320807 time to complete
# step 825 is completed! and taken 0:00:00.982543 time to complete
# step 826 is completed! and taken 0:00:01.215706 time to complete
# step 827 is completed! and taken 0:00:01.047825 time to complete
# step 828 is completed! and taken 0:00:01.156077 time to complete
# step 829 is completed! and taken 0:00:01.117679 time to complete
# step 830 is completed! and taken 0:00:00.966072 time to complete
# step 831 is completed! and taken 0:00:01.034160 time to complete
# step 832 is completed! and taken 0:00:01.143501 time to complete
# step 833 is completed! and taken 0:00:01.120879 time to complete
# step 834 is completed! and taken 0:00:01.019092 time to complete
# step 835 is completed! and taken 0:00:01.263360 time to complete
# step 836 is completed! and taken 0:00:01.021940 time to complete
# step 837 is completed! and taken 0:00:01.027989 time to complete
# step 838 is completed! and taken 0:00:01.077531 time to complete
# step 839 is completed! and taken 0:00:00.930853 time to complete
# step 840 is completed! and taken 0:00:00.945593 time to complete
# step 841 is completed! and taken 0:00:00.983271 time to complete
# step 842 is completed! and taken 0:00:00.915281 time to complete
# step 843 is completed! and taken 0:00:00.894576 time to complete
# step 844 is completed! and taken 0:00:00.966486 time to complete
# step 845 is completed! and taken 0:00:01.156932 time to complete
# step 846 is completed! and taken 0:00:01.025642 time to complete
# step 847 is completed! and taken 0:00:01.062907 time to complete
# step 848 is completed! and taken 0:00:01.078515 time to complete
# step 849 is completed! and taken 0:00:01.756824 time to complete
# step 850 is completed! and taken 0:00:01.298129 time to complete
# step 851 is completed! and taken 0:00:01.381740 time to complete
# step 852 is completed! and taken 0:00:01.169573 time to complete
# step 853 is completed! and taken 0:00:01.048050 time to complete
# step 854 is completed! and taken 0:00:01.117919 time to complete
# step 855 is completed! and taken 0:00:01.025946 time to complete
# step 856 is completed! and taken 0:00:01.030579 time to complete
# step 857 is completed! and taken 0:00:01.131368 time to complete
# step 858 is completed! and taken 0:00:01.253868 time to complete
# step 859 is completed! and taken 0:00:01.033266 time to complete
# step 860 is completed! and taken 0:00:01.086074 time to complete
# step 861 is completed! and taken 0:00:00.979797 time to complete
# step 862 is completed! and taken 0:00:01.121914 time to complete
# step 863 is completed! and taken 0:00:01.055206 time to complete
# step 864 is completed! and taken 0:00:01.155304 time to complete
# step 865 is completed! and taken 0:00:01.302826 time to complete
# step 866 is completed! and taken 0:00:01.005939 time to complete
# step 867 is completed! and taken 0:00:00.980271 time to complete
# step 868 is completed! and taken 0:00:01.046251 time to complete
# step 869 is completed! and taken 0:00:00.910735 time to complete
# step 870 is completed! and taken 0:00:01.227638 time to complete
# step 871 is completed! and taken 0:00:01.002914 time to complete
# step 872 is completed! and taken 0:00:01.015840 time to complete
# step 873 is completed! and taken 0:00:01.093416 time to complete
# step 874 is completed! and taken 0:00:01.037869 time to complete
# step 875 is completed! and taken 0:00:00.998528 time to complete
# step 876 is completed! and taken 0:00:00.994708 time to complete
# step 877 is completed! and taken 0:00:01.037337 time to complete
# step 878 is completed! and taken 0:00:01.541580 time to complete
# step 879 is completed! and taken 0:00:01.182754 time to complete
# step 880 is completed! and taken 0:00:01.196395 time to complete
# step 881 is completed! and taken 0:00:01.177930 time to complete
# step 882 is completed! and taken 0:00:01.108676 time to complete
# step 883 is completed! and taken 0:00:01.433329 time to complete
# step 884 is completed! and taken 0:00:01.205575 time to complete
# step 885 is completed! and taken 0:00:01.077262 time to complete
# step 886 is completed! and taken 0:00:01.766987 time to complete
# step 887 is completed! and taken 0:00:01.075707 time to complete
# step 888 is completed! and taken 0:00:01.041236 time to complete
# step 889 is completed! and taken 0:00:00.932028 time to complete
# step 890 is completed! and taken 0:00:00.924086 time to complete
# step 891 is completed! and taken 0:00:00.835727 time to complete
# step 892 is completed! and taken 0:00:01.041412 time to complete
# step 893 is completed! and taken 0:00:01.084188 time to complete
# step 894 is completed! and taken 0:00:01.010915 time to complete
# step 895 is completed! and taken 0:00:01.177303 time to complete
# step 896 is completed! and taken 0:00:00.897694 time to complete
# step 897 is completed! and taken 0:00:01.045689 time to complete
# step 898 is completed! and taken 0:00:00.924483 time to complete
# step 899 is completed! and taken 0:00:00.974667 time to complete
# step 900 is completed! and taken 0:00:00.876496 time to complete
# step 901 is completed! and taken 0:00:01.012772 time to complete
# step 902 is completed! and taken 0:00:01.135423 time to complete
# step 903 is completed! and taken 0:00:01.149091 time to complete
# step 904 is completed! and taken 0:00:00.959465 time to complete
# step 905 is completed! and taken 0:00:00.965239 time to complete
# step 906 is completed! and taken 0:00:01.035018 time to complete
# step 907 is completed! and taken 0:00:01.024672 time to complete
# step 908 is completed! and taken 0:00:01.014185 time to complete
# step 909 is completed! and taken 0:00:00.948586 time to complete
# step 910 is completed! and taken 0:00:00.961414 time to complete
# step 911 is completed! and taken 0:00:01.049847 time to complete
# step 912 is completed! and taken 0:00:01.055815 time to complete
# step 913 is completed! and taken 0:00:00.999451 time to complete
# step 914 is completed! and taken 0:00:00.895535 time to complete
# step 915 is completed! and taken 0:00:01.363746 time to complete
# step 916 is completed! and taken 0:00:01.360463 time to complete
# step 917 is completed! and taken 0:00:02.790641 time to complete
# step 918 is completed! and taken 0:00:00.968559 time to complete
# step 919 is completed! and taken 0:00:01.000851 time to complete
# step 920 is completed! and taken 0:00:01.092648 time to complete
# step 921 is completed! and taken 0:00:00.936621 time to complete
# step 922 is completed! and taken 0:00:00.981561 time to complete
# step 923 is completed! and taken 0:00:01.024949 time to complete
# step 924 is completed! and taken 0:00:01.107137 time to complete
# step 925 is completed! and taken 0:00:00.927195 time to complete
# step 926 is completed! and taken 0:00:00.919671 time to complete
# step 927 is completed! and taken 0:00:01.154107 time to complete
# step 928 is completed! and taken 0:00:00.982283 time to complete
# step 929 is completed! and taken 0:00:00.989292 time to complete
# step 930 is completed! and taken 0:00:00.986818 time to complete
# step 931 is completed! and taken 0:00:00.952052 time to complete
# step 932 is completed! and taken 0:00:01.240643 time to complete
# step 933 is completed! and taken 0:00:00.942450 time to complete
# step 934 is completed! and taken 0:00:00.927202 time to complete
# step 935 is completed! and taken 0:00:00.897567 time to complete
# step 936 is completed! and taken 0:00:00.949847 time to complete
# step 937 is completed! and taken 0:00:01.229385 time to complete
# step 938 is completed! and taken 0:00:01.049652 time to complete
# step 939 is completed! and taken 0:00:00.862201 time to complete
# step 940 is completed! and taken 0:00:00.931598 time to complete
# step 941 is completed! and taken 0:00:01.063795 time to complete
# step 942 is completed! and taken 0:00:00.908996 time to complete
# step 943 is completed! and taken 0:00:01.250368 time to complete
# step 944 is completed! and taken 0:00:01.067010 time to complete
# step 945 is completed! and taken 0:00:00.943428 time to complete
# step 946 is completed! and taken 0:00:00.936254 time to complete
# step 947 is completed! and taken 0:00:00.921433 time to complete
# step 948 is completed! and taken 0:00:01.008322 time to complete
# step 949 is completed! and taken 0:00:00.912574 time to complete
# step 950 is completed! and taken 0:00:01.080035 time to complete
# step 951 is completed! and taken 0:00:00.936832 time to complete
# step 952 is completed! and taken 0:00:01.069910 time to complete
# step 953 is completed! and taken 0:00:01.286204 time to complete
# step 954 is completed! and taken 0:00:00.933543 time to complete
# step 955 is completed! and taken 0:00:00.938838 time to complete
# step 956 is completed! and taken 0:00:00.971295 time to complete
# step 957 is completed! and taken 0:00:01.024748 time to complete
# step 958 is completed! and taken 0:00:00.871476 time to complete
# step 959 is completed! and taken 0:00:01.475555 time to complete
# step 960 is completed! and taken 0:00:01.019946 time to complete
# step 961 is completed! and taken 0:00:01.469561 time to complete
# step 962 is completed! and taken 0:00:01.260524 time to complete
# step 963 is completed! and taken 0:00:01.800687 time to complete
# step 964 is completed! and taken 0:00:01.528575 time to complete
# step 965 is completed! and taken 0:00:00.911787 time to complete
# step 966 is completed! and taken 0:00:01.181279 time to complete
# step 967 is completed! and taken 0:00:01.412722 time to complete
# step 968 is completed! and taken 0:00:00.870219 time to complete
# step 969 is completed! and taken 0:00:01.862499 time to complete
# step 970 is completed! and taken 0:00:01.001363 time to complete
# step 971 is completed! and taken 0:00:00.993611 time to complete
# step 972 is completed! and taken 0:00:01.168845 time to complete
# step 973 is completed! and taken 0:00:01.003819 time to complete
# step 974 is completed! and taken 0:00:01.557660 time to complete
# step 975 is completed! and taken 0:00:00.926878 time to complete
# step 976 is completed! and taken 0:00:01.096231 time to complete
# step 977 is completed! and taken 0:00:01.208659 time to complete
# step 978 is completed! and taken 0:00:00.963386 time to complete
# step 979 is completed! and taken 0:00:00.962066 time to complete
# step 980 is completed! and taken 0:00:00.982296 time to complete
# step 981 is completed! and taken 0:00:00.975327 time to complete
# step 982 is completed! and taken 0:00:00.923360 time to complete
# step 983 is completed! and taken 0:00:01.179724 time to complete
# step 984 is completed! and taken 0:00:00.908226 time to complete
# step 985 is completed! and taken 0:00:00.956605 time to complete
# step 986 is completed! and taken 0:00:01.069019 time to complete
# step 987 is completed! and taken 0:00:00.966176 time to complete
# step 988 is completed! and taken 0:00:00.982272 time to complete
# step 989 is completed! and taken 0:00:01.002068 time to complete
# step 990 is completed! and taken 0:00:00.867237 time to complete
# the programe take: 0:17:51.804729 to complete

# %%
grid_point_Weather_data.head()
# Out:
#                               Time  Id   Longitude   Latitude  Tempreture  \
# 0 2023-11-28 22:53:55.606668+11:00   1  143.251973 -35.083201       16.92
# 1 2023-11-28 22:53:55.606668+11:00   2  143.251973 -35.084201       16.92
# 2 2023-11-28 22:53:55.606668+11:00   3  143.251973 -35.085201       16.92
# 3 2023-11-28 22:53:55.606668+11:00   4  143.251973 -35.086201       16.92
# 4 2023-11-28 22:53:56.491730+11:00   5  143.251973 -35.087201       16.93
#
#    Humidity  Wind speed  Weather ID Weather ID group Weather ID description  \
# 0        89        5.48         500             Rain             light rain
# 1        89        5.48         500             Rain             light rain
# 2        89        5.48         500             Rain             light rain
# 3        89        5.48         500             Rain             light rain
# 4        89        5.45         500             Rain             light rain
#
#                Sunrise               Sunset
# 0  2023-11-28 05:07:11  2023-11-28 19:22:34
# 1  2023-11-28 05:07:11  2023-11-28 19:22:34
# 2  2023-11-28 05:07:11  2023-11-28 19:22:34
# 3  2023-11-28 05:07:11  2023-11-28 19:22:34
# 4  2023-11-28 05:07:11  2023-11-28 19:22:35

# %% [markdown]
# ### Preprocessing and feature engineering

# %%
# convert string type timedate data in to dateime type data
grid_point_Weather_data['Sunrise'] = pd.to_datetime(grid_point_Weather_data['Sunrise'], format='%Y-%m-%d %H:%M:%S')
grid_point_Weather_data['Sunset'] = pd.to_datetime(grid_point_Weather_data['Sunset'], format='%Y-%m-%d %H:%M:%S')

# %%
grid_point_Weather_data.head(10)
# Out:
#                               Time  Id   Longitude   Latitude  Tempreture  \
# 0 2023-11-28 22:53:55.606668+11:00   1  143.251973 -35.083201       16.92
# 1 2023-11-28 22:53:55.606668+11:00   2  143.251973 -35.084201       16.92
# 2 2023-11-28 22:53:55.606668+11:00   3  143.251973 -35.085201       16.92
# 3 2023-11-28 22:53:55.606668+11:00   4  143.251973 -35.086201       16.92
# 4 2023-11-28 22:53:56.491730+11:00   5  143.251973 -35.087201       16.93
# 5 2023-11-28 22:53:56.491730+11:00   6  143.251973 -35.088201       16.93
# 6 2023-11-28 22:53:56.491730+11:00   7  143.251973 -35.089201       16.93
# 7 2023-11-28 22:53:56.491730+11:00   8  143.251973 -35.090201       16.93
# 8 2023-11-28 22:53:57.558716+11:00   9  143.251973 -35.091201       16.93
# 9 2023-11-28 22:53:57.558716+11:00  10  143.251973 -35.092201       16.93
#
#    Humidity  Wind speed  Weather ID Weather ID group Weather ID description  \
# 0        89        5.48         500             Rain             light rain
# 1        89        5.48         500             Rain             light rain
# 2        89        5.48         500             Rain             light rain
# 3        89        5.48         500             Rain             light rain
# 4        89        5.45         500             Rain             light rain
# 5        89        5.45         500             Rain             light rain
# 6        89        5.45         500             Rain             light rain
# 7        89        5.45         500             Rain             light rain
# 8        89        5.45         500             Rain             light rain
# 9        89        5.45         500             Rain             light rain
#
#               Sunrise              Sunset
# 0 2023-11-28 05:07:11 2023-11-28 19:22:34
# 1 2023-11-28 05:07:11 2023-11-28 19:22:34
# 2 2023-11-28 05:07:11 2023-11-28 19:22:34
# 3 2023-11-28 05:07:11 2023-11-28 19:22:34
# 4 2023-11-28 05:07:11 2023-11-28 19:22:35
# 5 2023-11-28 05:07:11 2023-11-28 19:22:35
# 6 2023-11-28 05:07:11 2023-11-28 19:22:35
# 7 2023-11-28 05:07:11 2023-11-28 19:22:35
# 8 2023-11-28 05:07:11 2023-11-28 19:22:35
# 9 2023-11-28 05:07:11 2023-11-28 19:22:35

# %% [markdown]
# #### Feature1: solar activation time

# %%
Sunrise = grid_point_Weather_data["Sunrise"]
Sunset = grid_point_Weather_data["Sunset"]

# find the solar activation time
time_diffrence_arr = find_solar_seconds(Sunrise,Sunset)
time_diffrence_arr
# Out:
# array([51323, 51323, 51323, ..., 51338, 51338, 51338])

# %%
grid_point_Weather_data["Solar activation sconds"] = time_diffrence_arr

# %%
grid_point_Weather_data.head()
# Out:
#                               Time  Id   Longitude   Latitude  Tempreture  \
# 0 2023-11-28 22:53:55.606668+11:00   1  143.251973 -35.083201       16.92
# 1 2023-11-28 22:53:55.606668+11:00   2  143.251973 -35.084201       16.92
# 2 2023-11-28 22:53:55.606668+11:00   3  143.251973 -35.085201       16.92
# 3 2023-11-28 22:53:55.606668+11:00   4  143.251973 -35.086201       16.92
# 4 2023-11-28 22:53:56.491730+11:00   5  143.251973 -35.087201       16.93
#
#    Humidity  Wind speed  Weather ID Weather ID group Weather ID description  \
# 0        89        5.48         500             Rain             light rain
# 1        89        5.48         500             Rain             light rain
# 2        89        5.48         500             Rain             light rain
# 3        89        5.48         500             Rain             light rain
# 4        89        5.45         500             Rain             light rain
#
#               Sunrise              Sunset  Solar activation sconds
# 0 2023-11-28 05:07:11 2023-11-28 19:22:34                    51323
# 1 2023-11-28 05:07:11 2023-11-28 19:22:34                    51323
# 2 2023-11-28 05:07:11 2023-11-28 19:22:34                    51323
# 3 2023-11-28 05:07:11 2023-11-28 19:22:34                    51323
# 4 2023-11-28 05:07:11 2023-11-28 19:22:35                    51324

# %%
# create a date column as first column
date_column = grid_point_Weather_data["Sunrise"].apply(lambda x: ((str(x)).split())[0])
grid_point_Weather_data.insert(0, "Date",date_column)

# update the Time column
grid_point_Weather_data["Time"] = grid_point_Weather_data["Time"].apply(lambda x: (str(x)).split()[1][:11])

# %%
grid_point_Weather_data
# Out:
#             Date         Time    Id   Longitude   Latitude  Tempreture  \
# 0     2023-11-28  22:53:55.60     1  143.251973 -35.083201       16.92
# 1     2023-11-28  22:53:55.60     2  143.251973 -35.084201       16.92
# 2     2023-11-28  22:53:55.60     3  143.251973 -35.085201       16.92
# 3     2023-11-28  22:53:55.60     4  143.251973 -35.086201       16.92
# 4     2023-11-28  22:53:56.49     5  143.251973 -35.087201       16.93
# ...          ...          ...   ...         ...        ...         ...
# 3955  2023-11-28  23:11:45.54  3956  143.316973 -35.138201       16.83
# 3956  2023-11-28  23:11:46.54  3957  143.316973 -35.139201       16.83
# 3957  2023-11-28  23:11:46.54  3958  143.316973 -35.140201       16.83
# 3958  2023-11-28  23:11:46.54  3959  143.316973 -35.141201       16.83
# 3959  2023-11-28  23:11:46.54  3960  143.316973 -35.142201       16.83
#
#       Humidity  Wind speed  Weather ID Weather ID group  \
# 0           89        5.48         500             Rain
# 1           89        5.48         500             Rain
# 2           89        5.48         500             Rain
# 3           89        5.48         500             Rain
# 4           89        5.45         500             Rain
# ...        ...         ...         ...              ...
# 3955        90        5.46         500             Rain
# 3956        90        5.46         500             Rain
# 3957        90        5.46         500             Rain
# 3958        90        5.46         500             Rain
# 3959        90        5.46         500             Rain
#
#      Weather ID description             Sunrise              Sunset  \
# 0                light rain 2023-11-28 05:07:11 2023-11-28 19:22:34
# 1                light rain 2023-11-28 05:07:11 2023-11-28 19:22:34
# 2                light rain 2023-11-28 05:07:11 2023-11-28 19:22:34
# 3                light rain 2023-11-28 05:07:11 2023-11-28 19:22:34
# 4                light rain 2023-11-28 05:07:11 2023-11-28 19:22:35
# ...                     ...                 ...                 ...
# 3955             light rain 2023-11-28 05:06:48 2023-11-28 19:22:26
# 3956             light rain 2023-11-28 05:06:48 2023-11-28 19:22:26
# 3957             light rain 2023-11-28 05:06:48 2023-11-28 19:22:26
# 3958             light rain 2023-11-28 05:06:48 2023-11-28 19:22:26
# 3959             light rain 2023-11-28 05:06:48 2023-11-28 19:22:26
#
#       Solar activation sconds
# 0                       51323
# 1                       51323
# 2                       51323
# 3                       51323
# 4                       51324
# ...                       ...
# 3955                    51338
# 3956                    51338
# 3957                    51338
# 3958                    51338
# 3959                    51338
#
# [3960 rows x 14 columns]

# %%
grid_point_Weather_data.isnull().sum()
# Out:
# Date                       0
# Time                       0
# Id                         0
# Longitude                  0
# Latitude                   0
# Tempreture                 0
# Humidity                   0
# Wind speed                 0
# Weather ID                 0
# Weather ID group           0
# Weather ID description     0
# Sunrise                    0
# Sunset                     0
# Solar activation sconds    0
# dtype: int64

# %%
grid_point_Weather_data.to_csv("./results/csv/weather_dataset.csv", index=False)

# %% [markdown]
# ### Testing  code

# %%
lat  = latitudes[0]
long = longitudes[0]

# %%
url = "https://api.openweathermap.org/data/2.5/weather?lat={}&lon={}&appid=8ee842d65cf08ec205365865e3d53348&units=metric".format(lat,long)

# %%
res = requests.get(url)
data = res.json()

# %%
data
# Out:
# {'coord': {'lon': 143.252, 'lat': -35.0832},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 16.58,
#   'feels_like': 16.64,
#   'temp_min': 16.58,
#   'temp_max': 16.58,
#   'pressure': 1004,
#   'humidity': 90,
#   'sea_level': 1004,
#   'grnd_level': 996},
#  'visibility': 10000,
#  'wind': {'speed': 5.01, 'deg': 161, 'gust': 9.17},
#  'clouds': {'all': 85},
#  'dt': 1701188583,
#  'sys': {'country': 'AU', 'sunrise': 1701198415, 'sunset': 1701249811},
#  'timezone': 39600,
#  'id': 2153292,
#  'name': 'Piangil',
#  'cod': 200}

# %%
data["wind"]["speed"]

# %%
data["weather"][0]["main"]
